# %%
# !pip install transformers torch

# %%
from transformers import GPT2Tokenizer, GPT2LMHeadModel
import torch

# %%
# Load tokenizer
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")

# Load model
model = GPT2LMHeadModel.from_pretrained("gpt2")

# Set model to evaluation mode
model.eval()

# %%
prompt = "Once upon a time in a beach"

# Encode text → tokens
input_ids = tokenizer.encode(prompt, return_tensors="pt")

# Generate output
output_ids = model.generate(
    input_ids,
    max_length=420,
    do_sample=True,
    temperature=0.9,
    top_k=69,
    top_p=0.9
)

# Decode tokens → text
output_text = tokenizer.decode(output_ids[0], skip_special_tokens=True)
print(output_text)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Once upon a time in a beach somewhere, the sun is shining over the horizon. In this sense, it is a very special and strange place, in its very nature. It is as close as the sun can get to the surface of the earth. And to see that it does so with such sudden, unearthly and extraordinary splendour would be remarkable. And yet, that this is the most extraordinary and extraordinary place is not to be found in any other land, at any other time on earth, in any other period of time, for it is not within the scope of this article. It is only in the last thirty years or so, when I came here, that the place of my study and of the other people who are here, and who have been there for twenty years or more, has become much more like the surface of the sun, as the earth's atmosphere has increased and its surface has diminished. This has happened very recently, and it is a very peculiar matter. The ground which is now so fine and so clean, the ground of the earth, which is so strong, is very brittle and delicate. But, it is also not very so smooth and smooth and so thick and so thin. It is not very smooth and thick. In fact, the earth, upon which the sun and the Earth are based, is as smooth as the earth of the sun. The water which has come from the mountains, and which has come from the sea, which has come from the mountains, has come from the sea. The earth is so much thinner and thicker in its interior than in the ground. Now, I do not wish to say, as I shall say, that the earth is as smooth as the earth of the sun, for I think that the earth itself is quite so. It is no smaller than the earth in diameter. But, what is there in the earth? In the surface, it is nothing but a pile of water. The surface is still as smooth as the earth. The ground is very smooth and thick. I have already stated this,
